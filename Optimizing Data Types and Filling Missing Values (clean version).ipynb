# %% [markdown]
# # Credit Risk — Optimizing Data Types & Dealing with Missing Values
# ### for CEBD1260: Introduction to Machine Learning
# *by Pierre-Olivier Bonin*

# %% [markdown]
# # Importing Libraries and Loading the Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import linear_model
import statsmodels.formula.api as smf
import statsmodels.api as sm
import glob

DATA_PATH = 'D:\\Documents\\Pierre-Olivier\\CEBD1260\\Datasets\\'
all_files = glob.glob(DATA_PATH+'*.csv')
print(f"There are {len(all_files)} files to work with.") # print all files in the data directory

desc_df = pd.read_csv("D:/Documents/Pierre-Olivier/CEBD1260/Datasets/HomeCredit.csv", encoding="latin1")
desc_df = desc_df.drop("Unnamed: 0", axis=1)
maindf = pd.read_csv("D:/Documents/Pierre-Olivier/CEBD1260/Datasets/application_train.csv")
df2 = pd.read_csv("D:/Documents/Pierre-Olivier/CEBD1260/Datasets/bureau.csv")
df3 = pd.read_csv("D:/Documents/Pierre-Olivier/CEBD1260/Datasets/bureau_balance.csv")
df4 = pd.read_csv("D:/Documents/Pierre-Olivier/CEBD1260/Datasets/credit_card_balance.csv")
df5 =  pd.read_csv("D:/Documents/Pierre-Olivier/CEBD1260/Datasets/installments_payments.csv")
df6 = pd.read_csv("D:/Documents/Pierre-Olivier/CEBD1260/Datasets/POS_CASH_balance.csv")
df7 = pd.read_csv("D:/Documents/Pierre-Olivier/CEBD1260/Datasets/previous_application.csv")

dflist = [maindf, df2, df3, df4, df5, df6, df7]

desc_df['Table'].unique(), desc_df['Table'].nunique() # but we know that we actually have 7 datasets to work with.
print(f"There are {desc_df['Table'].nunique()} datasets to work with.")
# Out:
# There are 10 files to work with.

# %% [markdown]
# # Data Type Optimization

# %%
### INSTRUCTIONS ###
# To execute the present script, load the datasets to be cleaned and then put them into a list of dataframes.
# We will call the dataframe list 'dflist', such that you must run first the following:
# dflist = [] <-- here you insert your dataframes and separate with commas. Once you're done, run the script below.


# Print initial memory usage details
mem_sum = 0
for i in dflist:
    print('Memory usage of dataframe is {:.6f} GB'.format(i.memory_usage().sum()/1000000000))
    mem_sum = mem_sum+i.memory_usage().sum()/1000000000
print(f"Total memory used for all dataframes is: {mem_sum:.2f}GB")

# Construct dataframe for reference used below in the optimize_inttypes function.
np_types = [np.int8 ,np.int16 ,np.int32, np.int64,
           np.uint8 ,np.uint16, np.uint32, np.uint64]
np_types = [np_type.__name__ for np_type in np_types]
type_df = pd.DataFrame(data=np_types, columns=['class_type'])
type_df['min_value'] = type_df['class_type'].apply(lambda row: np.iinfo(row).min)
type_df['max_value'] = type_df['class_type'].apply(lambda row: np.iinfo(row).max)
type_df['range'] = type_df['max_value'] - type_df['min_value']
type_df.sort_values(by='range', inplace=True)

# Create function to optimize integer data types
def optimize_inttypes(dataframe):
    for col in dataframe.loc[:, dataframe.dtypes <= np.int64]:
        col_min = dataframe[col].min()
        col_max = dataframe[col].max()
        temp = type_df[(type_df['min_value'] <= col_min) & (type_df['max_value'] >= col_max)]
        optimized_class = temp.loc[temp['range'].idxmin(), 'class_type']
        print("Col name : {} Col min_value : {} Col max_value : {} Optimized Class : {}".format(col, col_min, col_max, optimized_class))
        dataframe[col] = dataframe[col].astype(optimized_class)

# Run integer optimization over all dataframes.
for i in dflist:
    optimize_inttypes(i)

# Print updated memory usage details
mem_sum = 0
for i in dflist:
    print('Memory usage of dataframe is {:.6f} GB'.format(i.memory_usage().sum()/1000000000))
    mem_sum = mem_sum+i.memory_usage().sum()/1000000000
print(f"Total memory used for all dataframes is: {mem_sum:.2f}GB")

####################################################################################################
####################################################################################################

# Create dataframe for reference, used in the float optimization function further below.
np_types = [np.float16 ,np.float32, np.float64]
np_types = [np_type.__name__ for np_type in np_types]
floattype_df = pd.DataFrame(data=np_types, columns=['class_type'])
floattype_df['min_value'] = floattype_df['class_type'].apply(lambda row: np.finfo(row).min)
floattype_df['max_value'] = floattype_df['class_type'].apply(lambda row: np.finfo(row).max)
floattype_df['range'] = floattype_df['max_value'] - floattype_df['min_value']
floattype_df.sort_values(by='range', inplace=True)

# Create float optimization function.
def optimize_floattypes(dataframe):
    for col in dataframe.loc[:, dataframe.dtypes == np.float64]:
        col_min = dataframe[col].min()
        col_max = dataframe[col].max()
        temp = floattype_df[(floattype_df['min_value'] <= col_min) & (floattype_df['max_value'] >= col_max)]
        optimized_class = temp.loc[temp['range'].idxmin(), 'class_type']
        print("Col name : {} Col min_value : {} Col max_value : {} Optimized Class : {}".format(col, col_min, col_max, optimized_class))
        dataframe[col] = dataframe[col].astype(optimized_class)

# Run float optimization over all dataframes.
for i in dflist:
    optimize_floattypes(i)

# Print updated memory usage details
mem_sum = 0
for i in dflist:
    print('Memory usage of dataframe is {:.6f} GB'.format(i.memory_usage().sum()/1000000000))
    mem_sum = mem_sum+i.memory_usage().sum()/1000000000
print(f"Total memory used for all dataframes is: {mem_sum:.2f}GB")
# Out:
# Memory usage of dataframe is 0.300131 GB
# Memory usage of dataframe is 0.233434 GB
# Memory usage of dataframe is 0.655198 GB
# Memory usage of dataframe is 0.706618 GB
# Memory usage of dataframe is 0.870746 GB
# Memory usage of dataframe is 0.640087 GB
# Memory usage of dataframe is 0.494383 GB
# Total memory used for all dataframes is: 3.90GB
# Col name : SK_ID_CURR Col min_value : 100002 Col max_value : 456255 Optimized Class : int32
# Col name : TARGET Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : CNT_CHILDREN Col min_value : 0 Col max_value : 19 Optimized Class : int8
# Col name : DAYS_BIRTH Col min_value : -25229 Col max_value : -7489 Optimized Class : int16
# Col name : DAYS_EMPLOYED Col min_value : -17912 Col max_value : 365243 Optimized Class : int32
# Col name : DAYS_ID_PUBLISH Col min_value : -7197 Col max_value : 0 Optimized Class : int16
# Col name : FLAG_MOBIL Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_EMP_PHONE Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_WORK_PHONE Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_CONT_MOBILE Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_PHONE Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_EMAIL Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : REGION_RATING_CLIENT Col min_value : 1 Col max_value : 3 Optimized Class : int8
# Col name : REGION_RATING_CLIENT_W_CITY Col min_value : 1 Col max_value : 3 Optimized Class : int8
# Col name : HOUR_APPR_PROCESS_START Col min_value : 0 Col max_value : 23 Optimized Class : int8
# Col name : REG_REGION_NOT_LIVE_REGION Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : REG_REGION_NOT_WORK_REGION Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : LIVE_REGION_NOT_WORK_REGION Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : REG_CITY_NOT_LIVE_CITY Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : REG_CITY_NOT_WORK_CITY Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : LIVE_CITY_NOT_WORK_CITY Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_2 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_3 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_4 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_5 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_6 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_7 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_8 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_9 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_10 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_11 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_12 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_13 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_14 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_15 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_16 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_17 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_18 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_19 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_20 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : FLAG_DOCUMENT_21 Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : SK_ID_CURR Col min_value : 100001 Col max_value : 456255 Optimized Class : int32
# Col name : SK_ID_BUREAU Col min_value : 5000000 Col max_value : 6843457 Optimized Class : int32
# Col name : DAYS_CREDIT Col min_value : -2922 Col max_value : 0 Optimized Class : int16
# Col name : CREDIT_DAY_OVERDUE Col min_value : 0 Col max_value : 2792 Optimized Class : int16
# Col name : CNT_CREDIT_PROLONG Col min_value : 0 Col max_value : 9 Optimized Class : int8
# Col name : DAYS_CREDIT_UPDATE Col min_value : -41947 Col max_value : 372 Optimized Class : int32
# Col name : SK_ID_BUREAU Col min_value : 5001709 Col max_value : 6842888 Optimized Class : int32
# Col name : MONTHS_BALANCE Col min_value : -96 Col max_value : 0 Optimized Class : int8
# Col name : SK_ID_PREV Col min_value : 1000018 Col max_value : 2843496 Optimized Class : int32
# Col name : SK_ID_CURR Col min_value : 100006 Col max_value : 456250 Optimized Class : int32
# Col name : MONTHS_BALANCE Col min_value : -96 Col max_value : -1 Optimized Class : int8
# Col name : AMT_CREDIT_LIMIT_ACTUAL Col min_value : 0 Col max_value : 1350000 Optimized Class : int32
# Col name : CNT_DRAWINGS_CURRENT Col min_value : 0 Col max_value : 165 Optimized Class : uint8
# Col name : SK_DPD Col min_value : 0 Col max_value : 3260 Optimized Class : int16
# Col name : SK_DPD_DEF Col min_value : 0 Col max_value : 3260 Optimized Class : int16
# Col name : SK_ID_PREV Col min_value : 1000001 Col max_value : 2843499 Optimized Class : int32
# Col name : SK_ID_CURR Col min_value : 100001 Col max_value : 456255 Optimized Class : int32
# Col name : NUM_INSTALMENT_NUMBER Col min_value : 1 Col max_value : 277 Optimized Class : int16
# Col name : SK_ID_PREV Col min_value : 1000001 Col max_value : 2843499 Optimized Class : int32
# Col name : SK_ID_CURR Col min_value : 100001 Col max_value : 456255 Optimized Class : int32
# Col name : MONTHS_BALANCE Col min_value : -96 Col max_value : -1 Optimized Class : int8
# Col name : SK_DPD Col min_value : 0 Col max_value : 4231 Optimized Class : int16
# Col name : SK_DPD_DEF Col min_value : 0 Col max_value : 3595 Optimized Class : int16
# Col name : SK_ID_PREV Col min_value : 1000001 Col max_value : 2845382 Optimized Class : int32
# Col name : SK_ID_CURR Col min_value : 100001 Col max_value : 456255 Optimized Class : int32
# Col name : HOUR_APPR_PROCESS_START Col min_value : 0 Col max_value : 23 Optimized Class : int8
# Col name : NFLAG_LAST_APPL_IN_DAY Col min_value : 0 Col max_value : 1 Optimized Class : int8
# Col name : DAYS_DECISION Col min_value : -2922 Col max_value : -1 Optimized Class : int16
# Col name : SELLERPLACE_AREA Col min_value : -1 Col max_value : 4000000 Optimized Class : int32
# Memory usage of dataframe is 0.214335 GB
# Memory usage of dataframe is 0.180225 GB
# Memory usage of dataframe is 0.354899 GB
# Memory usage of dataframe is 0.560686 GB
# Memory usage of dataframe is 0.680270 GB
# Memory usage of dataframe is 0.370050 GB
# Memory usage of dataframe is 0.440937 GB
# Total memory used for all dataframes is: 2.80GB
# Col name : AMT_INCOME_TOTAL Col min_value : 25650.0 Col max_value : 117000000.0 Optimized Class : float32
# Col name : AMT_CREDIT Col min_value : 45000.0 Col max_value : 4050000.0 Optimized Class : float32
# Col name : AMT_ANNUITY Col min_value : 1615.5 Col max_value : 258025.5 Optimized Class : float32
# Col name : AMT_GOODS_PRICE Col min_value : 40500.0 Col max_value : 4050000.0 Optimized Class : float32
# Col name : REGION_POPULATION_RELATIVE Col min_value : 0.00029 Col max_value : 0.072508 Optimized Class : float16
# Col name : DAYS_REGISTRATION Col min_value : -24672.0 Col max_value : 0.0 Optimized Class : float16
# Col name : OWN_CAR_AGE Col min_value : 0.0 Col max_value : 91.0 Optimized Class : float16
# Col name : CNT_FAM_MEMBERS Col min_value : 1.0 Col max_value : 20.0 Optimized Class : float16
# Col name : EXT_SOURCE_1 Col min_value : 0.014568132 Col max_value : 0.962692771 Optimized Class : float16
# Col name : EXT_SOURCE_2 Col min_value : 8.17e-08 Col max_value : 0.854999666 Optimized Class : float16
# Col name : EXT_SOURCE_3 Col min_value : 0.000527265 Col max_value : 0.896009549 Optimized Class : float16
# Col name : APARTMENTS_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : BASEMENTAREA_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : YEARS_BEGINEXPLUATATION_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : YEARS_BUILD_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : COMMONAREA_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : ELEVATORS_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : ENTRANCES_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : FLOORSMAX_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : FLOORSMIN_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : LANDAREA_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : LIVINGAPARTMENTS_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : LIVINGAREA_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : NONLIVINGAPARTMENTS_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : NONLIVINGAREA_AVG Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : APARTMENTS_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : BASEMENTAREA_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : YEARS_BEGINEXPLUATATION_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : YEARS_BUILD_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : COMMONAREA_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : ELEVATORS_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : ENTRANCES_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : FLOORSMAX_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : FLOORSMIN_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : LANDAREA_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : LIVINGAPARTMENTS_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : LIVINGAREA_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : NONLIVINGAPARTMENTS_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : NONLIVINGAREA_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : APARTMENTS_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : BASEMENTAREA_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : YEARS_BEGINEXPLUATATION_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : YEARS_BUILD_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : COMMONAREA_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : ELEVATORS_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : ENTRANCES_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : FLOORSMAX_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : FLOORSMIN_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : LANDAREA_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : LIVINGAPARTMENTS_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : LIVINGAREA_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : NONLIVINGAPARTMENTS_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : NONLIVINGAREA_MEDI Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : TOTALAREA_MODE Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Col name : OBS_30_CNT_SOCIAL_CIRCLE Col min_value : 0.0 Col max_value : 348.0 Optimized Class : float16
# Col name : DEF_30_CNT_SOCIAL_CIRCLE Col min_value : 0.0 Col max_value : 34.0 Optimized Class : float16
# Col name : OBS_60_CNT_SOCIAL_CIRCLE Col min_value : 0.0 Col max_value : 344.0 Optimized Class : float16
# Col name : DEF_60_CNT_SOCIAL_CIRCLE Col min_value : 0.0 Col max_value : 24.0 Optimized Class : float16
# Col name : DAYS_LAST_PHONE_CHANGE Col min_value : -4292.0 Col max_value : 0.0 Optimized Class : float16
# Col name : AMT_REQ_CREDIT_BUREAU_HOUR Col min_value : 0.0 Col max_value : 4.0 Optimized Class : float16
# Col name : AMT_REQ_CREDIT_BUREAU_DAY Col min_value : 0.0 Col max_value : 9.0 Optimized Class : float16
# Col name : AMT_REQ_CREDIT_BUREAU_WEEK Col min_value : 0.0 Col max_value : 8.0 Optimized Class : float16
# Col name : AMT_REQ_CREDIT_BUREAU_MON Col min_value : 0.0 Col max_value : 27.0 Optimized Class : float16
# Col name : AMT_REQ_CREDIT_BUREAU_QRT Col min_value : 0.0 Col max_value : 261.0 Optimized Class : float16
# Col name : AMT_REQ_CREDIT_BUREAU_YEAR Col min_value : 0.0 Col max_value : 25.0 Optimized Class : float16
# Col name : DAYS_CREDIT_ENDDATE Col min_value : -42060.0 Col max_value : 31199.0 Optimized Class : float16
# Col name : DAYS_ENDDATE_FACT Col min_value : -42023.0 Col max_value : 0.0 Optimized Class : float16
# Col name : AMT_CREDIT_MAX_OVERDUE Col min_value : 0.0 Col max_value : 115987185.0 Optimized Class : float32
# Col name : AMT_CREDIT_SUM Col min_value : 0.0 Col max_value : 585000000.0 Optimized Class : float32
# Col name : AMT_CREDIT_SUM_DEBT Col min_value : -4705600.32 Col max_value : 170100000.0 Optimized Class : float32
# Col name : AMT_CREDIT_SUM_LIMIT Col min_value : -586406.115 Col max_value : 4705600.32 Optimized Class : float32
# Col name : AMT_CREDIT_SUM_OVERDUE Col min_value : 0.0 Col max_value : 3756681.0 Optimized Class : float32
# Col name : AMT_ANNUITY Col min_value : 0.0 Col max_value : 118453423.5 Optimized Class : float32
# Col name : AMT_BALANCE Col min_value : -420250.185 Col max_value : 1505902.185 Optimized Class : float32
# Col name : AMT_DRAWINGS_ATM_CURRENT Col min_value : -6827.31 Col max_value : 2115000.0 Optimized Class : float32
# Col name : AMT_DRAWINGS_CURRENT Col min_value : -6211.62 Col max_value : 2287098.315 Optimized Class : float32
# Col name : AMT_DRAWINGS_OTHER_CURRENT Col min_value : 0.0 Col max_value : 1529847.0 Optimized Class : float32
# Col name : AMT_DRAWINGS_POS_CURRENT Col min_value : 0.0 Col max_value : 2239274.16 Optimized Class : float32
# Col name : AMT_INST_MIN_REGULARITY Col min_value : 0.0 Col max_value : 202882.005 Optimized Class : float32
# Col name : AMT_PAYMENT_CURRENT Col min_value : 0.0 Col max_value : 4289207.445 Optimized Class : float32
# Col name : AMT_PAYMENT_TOTAL_CURRENT Col min_value : 0.0 Col max_value : 4278315.69 Optimized Class : float32
# Col name : AMT_RECEIVABLE_PRINCIPAL Col min_value : -423305.82 Col max_value : 1472316.795 Optimized Class : float32
# Col name : AMT_RECIVABLE Col min_value : -420250.185 Col max_value : 1493338.185 Optimized Class : float32
# Col name : AMT_TOTAL_RECEIVABLE Col min_value : -420250.185 Col max_value : 1493338.185 Optimized Class : float32
# Col name : CNT_DRAWINGS_ATM_CURRENT Col min_value : 0.0 Col max_value : 51.0 Optimized Class : float16
# Col name : CNT_DRAWINGS_OTHER_CURRENT Col min_value : 0.0 Col max_value : 12.0 Optimized Class : float16
# Col name : CNT_DRAWINGS_POS_CURRENT Col min_value : 0.0 Col max_value : 165.0 Optimized Class : float16
# Col name : CNT_INSTALMENT_MATURE_CUM Col min_value : 0.0 Col max_value : 120.0 Optimized Class : float16
# Col name : NUM_INSTALMENT_VERSION Col min_value : 0.0 Col max_value : 178.0 Optimized Class : float16
# Col name : DAYS_INSTALMENT Col min_value : -2922.0 Col max_value : -1.0 Optimized Class : float16
# Col name : DAYS_ENTRY_PAYMENT Col min_value : -4921.0 Col max_value : -1.0 Optimized Class : float16
# Col name : AMT_INSTALMENT Col min_value : 0.0 Col max_value : 3771487.845 Optimized Class : float32
# Col name : AMT_PAYMENT Col min_value : 0.0 Col max_value : 3771487.845 Optimized Class : float32
# Col name : CNT_INSTALMENT Col min_value : 1.0 Col max_value : 92.0 Optimized Class : float16
# Col name : CNT_INSTALMENT_FUTURE Col min_value : 0.0 Col max_value : 85.0 Optimized Class : float16
# Col name : AMT_ANNUITY Col min_value : 0.0 Col max_value : 418058.145 Optimized Class : float32
# Col name : AMT_APPLICATION Col min_value : 0.0 Col max_value : 6905160.0 Optimized Class : float32
# Col name : AMT_CREDIT Col min_value : 0.0 Col max_value : 6905160.0 Optimized Class : float32
# Col name : AMT_DOWN_PAYMENT Col min_value : -0.9 Col max_value : 3060045.0 Optimized Class : float32
# Col name : AMT_GOODS_PRICE Col min_value : 0.0 Col max_value : 6905160.0 Optimized Class : float32
# Col name : RATE_DOWN_PAYMENT Col min_value : -1.4978763414307848e-05 Col max_value : 1.0 Optimized Class : float16
# Col name : RATE_INTEREST_PRIMARY Col min_value : 0.0347812535418791 Col max_value : 1.0 Optimized Class : float16
# Col name : RATE_INTEREST_PRIVILEGED Col min_value : 0.3731501057082452 Col max_value : 1.0 Optimized Class : float16
# Col name : CNT_PAYMENT Col min_value : 0.0 Col max_value : 84.0 Optimized Class : float16
# Col name : DAYS_FIRST_DRAWING Col min_value : -2922.0 Col max_value : 365243.0 Optimized Class : float32
# Col name : DAYS_FIRST_DUE Col min_value : -2892.0 Col max_value : 365243.0 Optimized Class : float32
# Col name : DAYS_LAST_DUE_1ST_VERSION Col min_value : -2801.0 Col max_value : 365243.0 Optimized Class : float32
# Col name : DAYS_LAST_DUE Col min_value : -2889.0 Col max_value : 365243.0 Optimized Class : float32
# Col name : DAYS_TERMINATION Col min_value : -2874.0 Col max_value : 365243.0 Optimized Class : float32
# Col name : NFLAG_INSURED_ON_APPROVAL Col min_value : 0.0 Col max_value : 1.0 Optimized Class : float16
# Memory usage of dataframe is 0.096866 GB
# Memory usage of dataframe is 0.118434 GB
# Memory usage of dataframe is 0.354899 GB
# Memory usage of dataframe is 0.299544 GB
# Memory usage of dataframe is 0.326530 GB
# Memory usage of dataframe is 0.250034 GB
# Memory usage of dataframe is 0.324022 GB
# Total memory used for all dataframes is: 1.77GB

# %% [markdown]
# # Preprocessing Column Identifier

# %%
### INSTRUCTIONS ###
# To execute the present script, load the datasets to be cleaned and then put them into a list of dataframes.
# We will call the dataframe list 'dflist', such that you must run first the following:
# dflist = [] <-- here you insert your dataframes and separate with commas. Once you're done, run the script below.

preprocessing_cols = []
for df in dflist:
    non_objectCols = []
    for i,j in zip(df.dtypes.index, df.dtypes.values):
        if j!="object":
            non_objectCols.append(i)
    
    null_cols = []
    for i, j in zip(df.isnull().sum().index, df.isnull().sum().values):
        if j>0:
            null_cols.append(i)
    
    non_BooleanCols = []
    for i, j in zip(df.nunique().index, df.nunique().values):
        if j>2:
            non_BooleanCols.append(i)

    preprocessing_cols.append(list(set(non_objectCols).intersection(null_cols,non_BooleanCols)))

# %% [markdown]
# > think about packing this into a function (def)

# %%
preprocessing_cols
# Out:
# [['LIVINGAPARTMENTS_AVG',
#   'CNT_FAM_MEMBERS',
#   'YEARS_BUILD_MEDI',
#   'AMT_REQ_CREDIT_BUREAU_DAY',
#   'BASEMENTAREA_MODE',
#   'FLOORSMAX_MEDI',
#   'FLOORSMIN_MEDI',
#   'FLOORSMAX_AVG',
#   'COMMONAREA_MEDI',
#   'YEARS_BEGINEXPLUATATION_AVG',
#   'APARTMENTS_MEDI',
#   'ELEVATORS_AVG',
#   'NONLIVINGAREA_AVG',
#   'LANDAREA_MODE',
#   'AMT_ANNUITY',
#   'FLOORSMAX_MODE',
#   'NONLIVINGAPARTMENTS_MODE',
#   'AMT_REQ_CREDIT_BUREAU_HOUR',
#   'LIVINGAREA_AVG',
#   'AMT_GOODS_PRICE',
#   'NONLIVINGAREA_MEDI',
#   'COMMONAREA_MODE',
#   'DEF_60_CNT_SOCIAL_CIRCLE',
#   'EXT_SOURCE_2',
#   'FLOORSMIN_AVG',
#   'AMT_REQ_CREDIT_BUREAU_WEEK',
#   'ELEVATORS_MEDI',
#   'AMT_REQ_CREDIT_BUREAU_YEAR',
#   'APARTMENTS_AVG',
#   'OBS_60_CNT_SOCIAL_CIRCLE',
#   'LIVINGAREA_MEDI',
#   'EXT_SOURCE_3',
#   'TOTALAREA_MODE',
#   'YEARS_BUILD_MODE',
#   'LIVINGAPARTMENTS_MEDI',
#   'LIVINGAREA_MODE',
#   'EXT_SOURCE_1',
#   'ENTRANCES_AVG',
#   'ENTRANCES_MODE',
#   'APARTMENTS_MODE',
#   'AMT_REQ_CREDIT_BUREAU_QRT',
#   'NONLIVINGAREA_MODE',
#   'YEARS_BEGINEXPLUATATION_MEDI',
#   'AMT_REQ_CREDIT_BUREAU_MON',
#   'LIVINGAPARTMENTS_MODE',
#   'LANDAREA_AVG',
#   'NONLIVINGAPARTMENTS_MEDI',
#   'BASEMENTAREA_MEDI',
#   'ELEVATORS_MODE',
#   'DEF_30_CNT_SOCIAL_CIRCLE',
#   'DAYS_LAST_PHONE_CHANGE',
#   'BASEMENTAREA_AVG',
#   'LANDAREA_MEDI',
#   'ENTRANCES_MEDI',
#   'OWN_CAR_AGE',
#   'FLOORSMIN_MODE',
#   'OBS_30_CNT_SOCIAL_CIRCLE',
#   'YEARS_BEGINEXPLUATATION_MODE',
#   'NONLIVINGAPARTMENTS_AVG',
#   'YEARS_BUILD_AVG',
#   'COMMONAREA_AVG'],
#  ['AMT_CREDIT_MAX_OVERDUE',
#   'AMT_CREDIT_SUM_DEBT',
#   'DAYS_ENDDATE_FACT',
#   'AMT_CREDIT_SUM_LIMIT',
#   'DAYS_CREDIT_ENDDATE',
#   'AMT_ANNUITY',
#   'AMT_CREDIT_SUM'],
#  [],
#  ['AMT_DRAWINGS_ATM_CURRENT',
#   'AMT_DRAWINGS_POS_CURRENT',
#   'CNT_DRAWINGS_OTHER_CURRENT',
#   'CNT_DRAWINGS_ATM_CURRENT',
#   'AMT_INST_MIN_REGULARITY',
#   'CNT_INSTALMENT_MATURE_CUM',
#   'AMT_DRAWINGS_OTHER_CURRENT',
#   'CNT_DRAWINGS_POS_CURRENT',
#   'AMT_PAYMENT_CURRENT'],
#  ['DAYS_ENTRY_PAYMENT', 'AMT_PAYMENT'],
#  ['CNT_INSTALMENT', 'CNT_INSTALMENT_FUTURE'],
#  ['AMT_CREDIT',
#   'AMT_GOODS_PRICE',
#   'RATE_DOWN_PAYMENT',
#   'RATE_INTEREST_PRIVILEGED',
#   'DAYS_LAST_DUE_1ST_VERSION',
#   'DAYS_FIRST_DUE',
#   'DAYS_TERMINATION',
#   'DAYS_LAST_DUE',
#   'AMT_DOWN_PAYMENT',
#   'DAYS_FIRST_DRAWING',
#   'AMT_ANNUITY',
#   'RATE_INTEREST_PRIMARY',
#   'CNT_PAYMENT']]

# %% [markdown]
# feature engineering as another function
